# %% [markdown]
# # Implementing FER Python Library for the Set of Videos from 51-105

# %% [markdown]
# ## Installing FER Python Library

# %%
pip install FER
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\khizer ahmed\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\khizer ahmed\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\khizer ahmed\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\khizer ahmed\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\khizer ahmed\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\khizer ahmed\appdata\local\programs\python\python310\lib\site-packages)
# ...

# %% [markdown]
# ########## Source
# https://towardsdatascience.com/the-ultimate-guide-to-emotion-recognition-from-facial-expressions-using-python-64e58d4324ff

# %%
from tqdm import tqdm

# %% [markdown]
# ## FER on Images

# %%
## FER  on Images 


from fer import FER
import matplotlib.pyplot as plt 
# %matplotlib inline

test_image_one = plt.imread("angry.jfif")
emo_detector = FER(mtcnn=True)
# Capture all the emotions on the image
captured_emotions = emo_detector.detect_emotions(test_image_one)
# Print all captured emotions with the image
print(captured_emotions)
plt.imshow(test_image_one)

# Use the top Emotion() function to call for the dominant emotion in the image
dominant_emotion, emotion_score = emo_detector.top_emotion(test_image_one)
print(dominant_emotion, emotion_score)

# %%
pip install tqdm
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## FER on Videos

# %% [markdown]
# ### Importing the libraries

# %%
from fer import Video
from fer import FER
import os
import sys
import pandas as pd

# %% [markdown]
# ### Detecting Expressions in Videos using FER Python API

# %%
detected_emotions = []
def fer(location):
    # Put in the location of the video file that has to be processed
    location_videofile = location

    # Build the Face detection detector
    face_detector = FER(mtcnn=True)
    # Input the video for processing
    input_video = Video(location_videofile)

    # The Analyze() function will run analysis on every frame of the input video. 
    # It will create a rectangular box around every image and show the emotion values next to that.
    # Finally, the method will publish a new video that will have a box around the face of the human with live emotion values.
    processing_data = input_video.analyze(face_detector, display=False)

    # We will now convert the analysed information into a dataframe.
    # This will help us import the data as a .CSV file to perform analysis over it later
    vid_df = input_video.to_pandas(processing_data)
    vid_df = input_video.get_first_face(vid_df)
    vid_df = input_video.get_emotions(vid_df)

    # Plotting the emotions against time in the video
    # pltfig = vid_df.plot(figsize=(20, 8), fontsize=16).get_figure()

    # We will now work on the dataframe to extract which emotion was prominent in the video
    angry = sum(vid_df.angry)
    disgust = sum(vid_df.disgust)
    fear = sum(vid_df.fear)
    happy = sum(vid_df.happy)
    sad = sum(vid_df.sad)
    surprise = sum(vid_df.surprise)
    neutral = sum(vid_df.neutral)

    emotions = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']
    emotions_values = [angry, disgust, fear, happy, sad, surprise, neutral]

    score_comparisons = pd.DataFrame(emotions, columns = ['Human Emotions'])
    score_comparisons['Emotion Value from the Video'] = emotions_values
    for i in range (0, len(score_comparisons)):
        score = score_comparisons['Emotion Value from the Video'][i]
        if score == max(score_comparisons['Emotion Value from the Video']):
            detected_emotions.append(score_comparisons['Human Emotions'][i])

# %%
i = 71
while i <= 105:
#     if i == 10:
#         continue
    loc = "Vedios\Video " + str(i) + '.mp4'
    fer(loc)
    i = i+1
# Out:
# INFO:fer:25.00 fps, 548 frames, 21.92 seconds
# INFO:fer:Making directories at output
# 100%|████████████████████████████████████████████████████████████████████████████| 548/548 [18:07<00:00,  1.99s/frames]
# INFO:fer:Completed analysis: saved to output\Video 71_output.mp4
# INFO:fer:Starting to Zip
# INFO:fer:Compressing: 9%
# INFO:fer:Compressing: 18%
# INFO:fer:Compressing: 27%
# INFO:fer:Compressing: 36%
# INFO:fer:Compressing: 45%
# INFO:fer:Compressing: 54%
# INFO:fer:Compressing: 63%
# INFO:fer:Compressing: 72%
# INFO:fer:Compressing: 82%
# INFO:fer:Compressing: 91%
# INFO:fer:Zip has finished
# INFO:fer:25.00 fps, 500 frames, 20.00 seconds
# INFO:fer:Making directories at output
# 100%|████████████████████████████████████████████████████████████████████████████| 500/500 [16:59<00:00,  2.04s/frames]
# INFO:fer:Completed analysis: saved to output\Video 72_output.mp4
# INFO:fer:Starting to Zip
# INFO:fer:Compressing: 10%
# INFO:fer:Compressing: 20%
# INFO:fer:Compressing: 30%
# ...

# %%
fer("Vedios\Video 70.mp4")
# Out:
# INFO:fer:25.00 fps, 548 frames, 21.92 seconds
# INFO:fer:Making directories at output
# INFO:fer:Deleted pre-existing output\Video 70_output.mp4
# 100%|████████████████████████████████████████████████████████████████████████████| 548/548 [17:25<00:00,  1.91s/frames]
# INFO:fer:Completed analysis: saved to output\Video 70_output.mp4
# INFO:fer:Starting to Zip
# INFO:fer:Compressing: 9%
# INFO:fer:Compressing: 18%
# INFO:fer:Compressing: 27%
# INFO:fer:Compressing: 36%
# INFO:fer:Compressing: 45%
# INFO:fer:Compressing: 54%
# INFO:fer:Compressing: 63%
# INFO:fer:Compressing: 72%
# INFO:fer:Compressing: 82%
# INFO:fer:Compressing: 91%
# INFO:fer:Zip has finished

# %%
## List of emotions for the videos from 51-105

detected_emotions
# Out:
# ['Angry',
#  'Sad',
#  'Sad',
#  'Neutral',
#  'Fear',
#  'Sad',
#  'Neutral',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Neutral',
#  'Happy',
#  'Fear',
#  'Neutral',
#  'Sad',
#  'Neutral',
#  'Happy',
#  'Angry',
#  'Happy',
#  'Angry',
#  'Angry',
#  'Happy',
#  'Neutral',
#  'Neutral',
#  'Happy',
#  'Sad',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Neutral',
#  'Happy',
#  'Neutral',
#  'Neutral',
#  'Surprise',
#  'Happy',
#  'Neutral',
#  'Happy',
#  'Happy',
#  'Angry',
#  'Happy',
#  'Sad',
#  'Sad',
#  'Neutral',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Neutral',
#  'Happy',
#  'Happy',
#  'Neutral']

# %%
detected_emotions
# Out:
# ['Angry',
#  'Sad',
#  'Sad',
#  'Neutral',
#  'Fear',
#  'Sad',
#  'Neutral',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Neutral',
#  'Happy',
#  'Fear',
#  'Neutral',
#  'Sad',
#  'Neutral',
#  'Happy',
#  'Angry',
#  'Happy',
#  'Angry',
#  'Angry',
#  'Happy',
#  'Neutral',
#  'Neutral',
#  'Happy',
#  'Sad',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Neutral',
#  'Happy',
#  'Neutral',
#  'Neutral',
#  'Surprise',
#  'Happy',
#  'Neutral',
#  'Happy',
#  'Happy',
#  'Angry',
#  'Happy',
#  'Sad',
#  'Sad',
#  'Neutral',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Neutral',
#  'Happy',
#  'Happy']

# %%
df1 = pd.DataFrame()

# %%
len(df1)
# Out:
# 55

# %%
df1['emotion'] = detected_emotions

# %%
df1.to_csv('51-105.csv')

# %%
# %save detected_emotion
# Out:
# '' was not found in history, as a file, url, nor in the user namespace.

# %%
first = ['Angry',
 'Sad',
 'Sad',
 'Neutral',
 'Fear',
 'Sad',
 'Neutral',
 'Angry',
 'Angry',
 'Angry',
 'Neutral',
 'Happy',
 'Fear',
 'Neutral',
 'Sad',
 'Neutral',
 'Happy',
 'Angry',
 'Happy']
# %save first
# Out:
# '' was not found in history, as a file, url, nor in the user namespace.

# %%
# %save detected_emotions

# %%
from fer import FER
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
def classify(i):
    emo_detector = FER(mtcnn=True)
    # Capture all the emotions on the image
    captured_emotions = emo_detector.detect_emotions(i)
    dominant_emotion, emotion_score = emo_detector.top_emotion(i)
    return dominant_emotion

# %% [markdown]
# ## Evaluation of FER

# %%
import pandas as pd
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ground_truth_data = pd.read_csv('GroundTruthEmotions.csv')

# %%
ground_truth_data = ground_truth_data.drop(['Unnamed: 0'],axis=1)

# %%
ground_truth_data
# Out:
#     Video_Name Emotion_Identified
# 0      Video 0              Happy
# 1      Video 1            Disgust
# 2      Video 2              Angry
# 3      Video 3            Disgust
# 4      Video 4            Disgust
# ..         ...                ...
# 100  Video 101              Happy
# 101  Video 102            Neutral
# 102  Video 103            Neutral
# 103  Video 104            Neutral
# 104  Video 105              Happy
#
# [105 rows x 2 columns]

# %%
FER_emotions = pd.read_csv("FER_Results.csv")
FER_emotions.head()
# Out:
#    Video_Name  emotion
# 0           0    Happy
# 1           1      Sad
# 2           2    Angry
# 3           3      Sad
# 4           4  Neutral

# %%
pd.DataFrame(ground_truth_data['Emotion_Identified'].value_counts())
# Out:
#           Emotion_Identified
# Happy                     26
# Neutral                   23
# Angry                     20
# Sad                       16
# Surprise                   8
# Disgust                    7
# Fear                       5

# %%
ground_truth = ground_truth_data['Emotion_Identified']
FER_identified_emotions = FER_emotions['emotion']

# %%
print(metrics.classification_report(ground_truth,FER_identified_emotions))
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.76      0.65      0.70        20
#      Disgust       0.00      0.00      0.00         7
#         Fear       0.00      0.00      0.00         5
#        Happy       0.78      0.81      0.79        26
#      Neutral       0.52      0.61      0.56        23
#          Sad       0.33      0.56      0.42        16
#     Surprise       0.75      0.38      0.50         8
#
#     accuracy                           0.57       105
#    macro avg       0.45      0.43      0.42       105
# weighted avg       0.56      0.57      0.55       105
# C:\Users\Khizer Ahmed\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
confusion_matrix = metrics.confusion_matrix(ground_truth,FER_identified_emotions)
cm_df = pd.DataFrame(confusion_matrix,
                     index = ['ANGRY','DISGUST','FEAR','HAPPY','NEUTRAL','SAD','SURPRISE'], 
                     columns = ['ANGRY','DISGUST','FEAR','HAPPY','NEUTRAL','SAD','SURPRISE'])

# %%
cm_df
# Out:
#           ANGRY  DISGUST  FEAR  HAPPY  NEUTRAL  SAD  SURPRISE
# ANGRY        13        0     2      0        1    3         1
# DISGUST       2        0     0      0        3    2         0
# FEAR          0        0     0      1        0    4         0
# HAPPY         0        0     0     21        2    3         0
# NEUTRAL       1        0     1      2       14    5         0
# SAD           1        0     0      0        6    9         0
# SURPRISE      0        0     0      3        1    1         3

# %%
#Plotting the confusion matrix
plt.figure(figsize=(5,4))
sns.heatmap(cm_df, annot=True, cmap='Blues')
plt.title("")
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()

# %%
report = metrics.classification_report(ground_truth,FER_identified_emotions, output_dict=True)
# Out:
# C:\Users\Khizer Ahmed\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Khizer Ahmed\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
df = pd.DataFrame(report).transpose()

# %%
df
# Out:
#               precision    recall  f1-score     support
# Angry          0.764706  0.650000  0.702703   20.000000
# Disgust        0.000000  0.000000  0.000000    7.000000
# Fear           0.000000  0.000000  0.000000    5.000000
# Happy          0.777778  0.807692  0.792453   26.000000
# Neutral        0.518519  0.608696  0.560000   23.000000
# Sad            0.333333  0.562500  0.418605   16.000000
# Surprise       0.750000  0.375000  0.500000    8.000000
# accuracy       0.571429  0.571429  0.571429    0.571429
# macro avg      0.449191  0.429127  0.424823  105.000000
# weighted avg   0.559768  0.571429  0.554624  105.000000
